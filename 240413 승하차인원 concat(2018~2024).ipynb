# %%
import pandas as pd
import numpy as np

# %%
# 데이터 불러오기
df24 = pd.read_csv("./2024 승하차인원_행정동 추가.csv")
df23 = pd.read_csv("./2023 승하차인원_행정동 추가.csv")
df22 = pd.read_csv("./2022 승하차인원_행정동 추가.csv")
df21 = pd.read_csv("./2021 승하차인원_행정동 추가.csv")
df20 = pd.read_csv("./2020 승하차인원_행정동 추가.csv")
df19 = pd.read_csv("./2019 승하차인원_행정동 추가.csv")
df18 = pd.read_csv("./2018 승하차인원_행정동 추가.csv")

# %%
df24
# Out:
#                날짜       역명  구분  06시 이전  06시-07시  07시-08시  08시-09시  09시-10시  \
# 0      2023-11-01  1호선 서울역  승차     342      520     1929     2864     2321
# 1      2023-11-01  1호선 서울역  하차     300     2166     5186    10500     6808
# 2      2023-11-01  1호선 시청역  승차      86      157      303      415      513
# 3      2023-11-01  1호선 시청역  하차     220     1014     3464     9344     4223
# 4      2023-11-01  1호선 종각역  승차     144      167      256      454      559
# ...           ...      ...  ..     ...      ...      ...      ...      ...
# 47099  2024-01-31  8호선 문정역  하차     156      550     2598     8411     3505
# 47100  2024-01-31  8호선 장지역  승차     191      666     2058     2431     1272
# 47101  2024-01-31  8호선 장지역  하차     106      489     1111     1997     1161
# 47102  2024-01-31  8호선 복정역  승차     122      387     1238     1627      824
# 47103  2024-01-31  8호선 복정역  하차      84      312      452      661      338
#
#        10시-11시  11시-12시  ...   월   일  요일  분기         역전화번호  \
# ...

# %%
total = pd.concat([df24, df23, df22, df21, df20, df19, df18], ignore_index=False)
total
# Out:
#                 날짜       역명  구분  06시 이전  06시-07시  07시-08시  08시-09시  09시-10시  \
# 0       2023-11-01  1호선 서울역  승차     342      520     1929     2864     2321
# 1       2023-11-01  1호선 서울역  하차     300     2166     5186    10500     6808
# 2       2023-11-01  1호선 시청역  승차      86      157      303      415      513
# 3       2023-11-01  1호선 시청역  하차     220     1014     3464     9344     4223
# 4       2023-11-01  1호선 종각역  승차     144      167      256      454      559
# ...            ...      ...  ..     ...      ...      ...      ...      ...
# 185415  2018-12-31  8호선 문정역  하차      54      318      894     4233     1907
# 185416  2018-12-31  8호선 장지역  승차     163      470     1561     1738      971
# 185417  2018-12-31  8호선 장지역  하차      69      270      665     1674     1096
# 185418  2018-12-31  8호선 복정역  승차     128      328     1128     1322      776
# 185419  2018-12-31  8호선 복정역  하차      32      211      365      548      306
#
# ...

# %%
total.isna().sum()
# Out:
# 날짜              0
# 역명              0
# 구분              0
# 06시 이전          0
# 06시-07시         0
# 07시-08시         0
# 08시-09시         0
# 09시-10시         0
# 10시-11시         0
# 11시-12시         0
# 12시-13시         0
# 13시-14시         0
# 14시-15시         0
# 15시-16시         0
# 16시-17시         0
# 17시-18시         0
# 18시-19시         0
# 19시-20시         0
# 20시-21시         0
# 21시-22시         0
# 22시-23시         0
# 23시-24시         0
# 24시 이후     263638
# 연도              0
# 월               0
# 일               0
# 요일              0
# 분기              0
# 역전화번호           0
# 도로명주소           0
# 지번주소            0
# 행정동             0
# 위도              0
# 경도              0
# dtype: int64

# %%
print(total.dtypes)
# Out:
# 날짜          object
# 역명          object
# 구분          object
# 06시 이전       int64
# 06시-07시      int64
# 07시-08시      int64
# 08시-09시      int64
# 09시-10시      int64
# 10시-11시      int64
# 11시-12시      int64
# 12시-13시      int64
# 13시-14시      int64
# 14시-15시      int64
# 15시-16시      int64
# 16시-17시      int64
# 17시-18시      int64
# 18시-19시      int64
# 19시-20시      int64
# 20시-21시      int64
# 21시-22시      int64
# 22시-23시      int64
# 23시-24시      int64
# 24시 이후     float64
# 연도           int64
# 월            int64
# 일            int64
# 요일          object
# 분기           int64
# 역전화번호       object
# 도로명주소       object
# 지번주소        object
# 행정동         object
# 위도         float64
# 경도         float64
# dtype: object

# %%
# index를 포함하지 않고 데이터 저장
total.to_csv("승하차인원 concat(2018~2024).csv", index=False)
