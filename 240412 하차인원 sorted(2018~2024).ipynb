# %%
import pandas as pd
import numpy as np

# %%
# 데이터 불러오기
df24 = pd.read_csv("./2024 하차인원(1_8호선).csv")
df23 = pd.read_csv("./2023 하차인원(1_8호선).csv")
df22 = pd.read_csv("./2022 하차인원(1_8호선).csv")
df21 = pd.read_csv("./2021 하차인원(1_8호선).csv")
df20 = pd.read_csv("./2020 하차인원(1_8호선).csv")
df19 = pd.read_csv("./2019 하차인원(1_8호선).csv")
df18 = pd.read_csv("./2018 하차인원(1_8호선).csv")

# %% [markdown]
# 2024년

# %%
df24
# Out:
#                날짜   호선      역명  구분  06시 이전  06시-07시  07시-08시  08시-09시  \
# 0      2023-11-01  1호선     서울역  하차     300     2166     5186    10500
# 1      2023-11-01  1호선     시청역  하차     220     1014     3464     9344
# 2      2023-11-01  1호선     종각역  하차     238     1162     5429    12950
# 3      2023-11-01  1호선   종로3가역  하차     103      478     1154     3042
# 4      2023-11-01  1호선   종로5가역  하차     176      664     1813     4429
# ...           ...  ...     ...  ..     ...      ...      ...      ...
# 25114  2024-01-31  8호선  단대오거리역  하차      58      207      444      844
# 25115  2024-01-31  8호선     신흥역  하차      19       67      128      282
# 25116  2024-01-31  8호선     수진역  하차      28       73      136      290
# 25117  2024-01-31  8호선     모란역  하차      19      128      161      374
# 25118  2024-01-31  8호선    남위례역  하차      39      134      340      932
#
#        09시-10시  10시-11시  ...  20시-21시  21시-22시  22시-23시  23시-24시  24시 이후  \
# ...

# %%
# 각 분기별로 시간대별 승차 데이터를 큰 값부터 작은 값 순서로 sorted
df24_sorted =  df24.groupby('분기').apply(lambda x: x.sort_values(by=['06시 이전', '06시-07시', '07시-08시', '08시-09시', '09시-10시', '10시-11시',
                                                                    '11시-12시', '12시-13시', '13시-14시', '14시-15시', '15시-16시', '16시-17시',
                                                                    '17시-18시', '18시-19시', '19시-20시', '20시-21시', '21시-22시', '22시-23시',
                                                                    '23시-24시', '24시 이후'], ascending=False))
df24_sorted.head()
# Out:
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_4672\3476927732.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df24_sorted =  df24.groupby('분기').apply(lambda x: x.sort_values(by=['06시 이전', '06시-07시', '07시-08시', '08시-09시', '09시-10시', '10시-11시',
#                   날짜   호선   역명  구분  06시 이전  06시-07시  07시-08시  08시-09시  \
# 분기
# 1  24603  2024-01-30  2호선  강남역  하차     526     2272     6927    14287
#    20783  2024-01-16  2호선  강남역  하차     524     2262     7319    14345
#    19144  2024-01-10  2호선  강남역  하차     521     2365     7036    13749
#    24329  2024-01-29  2호선  강남역  하차     519     2348     7130    13842
#    22418  2024-01-22  2호선  강남역  하차     517     2346     6881    13528
#
# ...

# %%
# index를 포함하지 않고 데이터 저장
df24_sorted.to_csv("2024 분기별 하차인원 sorted.csv", index=False)
df24_sorted.head()
# Out:
#                   날짜   호선   역명  구분  06시 이전  06시-07시  07시-08시  08시-09시  \
# 분기
# 1  24603  2024-01-30  2호선  강남역  하차     526     2272     6927    14287
#    20783  2024-01-16  2호선  강남역  하차     524     2262     7319    14345
#    19144  2024-01-10  2호선  강남역  하차     521     2365     7036    13749
#    24329  2024-01-29  2호선  강남역  하차     519     2348     7130    13842
#    22418  2024-01-22  2호선  강남역  하차     517     2346     6881    13528
#
#           09시-10시  10시-11시  ...  20시-21시  21시-22시  22시-23시  23시-24시  24시 이후  \
# 분기                          ...
# 1  24603    13888     6347  ...     1959     1600     1196      646     260
#    20783    14657     6286  ...     1834     1427     1192      639     220
#    19144    14357     6246  ...     2027     1564     1310      725     233
#    24329    14164     6021  ...     1768     1343     1045      571     249
#    22418    14691     6380  ...     1766     1383     1051      462     209
#
#             연도  월   일  요일  분기
# 분기
# ...

# %% [markdown]
# 2023년

# %%
df23
# Out:
#                날짜   호선      역명  구분  06시 이전  06시-07시  07시-08시  08시-09시  \
# 0      2023-01-01  1호선     서울역  하차     154      636      595      939
# 1      2023-01-01  1호선     시청역  하차      64      247      293      463
# 2      2023-01-01  1호선     종각역  하차      69      164      268      384
# 3      2023-01-01  1호선   종로3가역  하차      39      118      130      274
# 4      2023-01-01  1호선   종로5가역  하차      26       84      130      216
# ...           ...  ...     ...  ..     ...      ...      ...      ...
# 82683  2023-10-31  8호선  단대오거리역  하차      60      230      485      992
# 82684  2023-10-31  8호선     신흥역  하차      12       73      152      290
# 82685  2023-10-31  8호선     수진역  하차      23      108      220      543
# 82686  2023-10-31  8호선     모란역  하차      22      136      214      465
# 82687  2023-10-31  8호선    남위례역  하차      43      118      334     1210
#
#        09시-10시  10시-11시  ...  20시-21시  21시-22시  22시-23시  23시-24시  24시 이후  \
# ...

# %%
# 각 분기별로 시간대별 승차 데이터를 큰 값부터 작은 값 순서로 sorted
df23_sorted =  df23.groupby('분기').apply(lambda x: x.sort_values(by=['06시 이전', '06시-07시', '07시-08시', '08시-09시', '09시-10시', '10시-11시',
                                                                    '11시-12시', '12시-13시', '13시-14시', '14시-15시', '15시-16시', '16시-17시',
                                                                    '17시-18시', '18시-19시', '19시-20시', '20시-21시', '21시-22시', '22시-23시',
                                                                    '23시-24시', '24시 이후'], ascending=False))
df23_sorted.head()
# Out:
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_4672\3931661248.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df23_sorted =  df23.groupby('분기').apply(lambda x: x.sort_values(by=['06시 이전', '06시-07시', '07시-08시', '08시-09시', '09시-10시', '10시-11시',
#                   날짜   호선   역명  구분  06시 이전  06시-07시  07시-08시  08시-09시  \
# 분기
# 1  9007   2023-02-03  2호선  강남역  하차     521     2101     6520    13021
#    8735   2023-02-02  2호선  강남역  하차     517     2097     6859    13778
#    10095  2023-02-07  2호선  강남역  하차     515     2201     6687    13873
#    10911  2023-02-10  2호선  강남역  하차     505     1920     6353    12497
#    15807  2023-02-28  2호선  강남역  하차     504     2106     6585    13119
#
# ...

# %%
# index를 포함하지 않고 데이터 저장
df23_sorted.to_csv("2023 분기별 하차인원 sorted.csv", index=False)
df23_sorted.head()
# Out:
#                   날짜   호선   역명  구분  06시 이전  06시-07시  07시-08시  08시-09시  \
# 분기
# 1  9007   2023-02-03  2호선  강남역  하차     521     2101     6520    13021
#    8735   2023-02-02  2호선  강남역  하차     517     2097     6859    13778
#    10095  2023-02-07  2호선  강남역  하차     515     2201     6687    13873
#    10911  2023-02-10  2호선  강남역  하차     505     1920     6353    12497
#    15807  2023-02-28  2호선  강남역  하차     504     2106     6585    13119
#
#           09시-10시  10시-11시  ...  20시-21시  21시-22시  22시-23시  23시-24시  24시 이후  \
# 분기                          ...
# 1  9007     13303     6256  ...     2394     1789     1588     1178     482
#    8735     13493     6037  ...     2092     1555     1375      732     348
#    10095    14399     6324  ...     2049     1581     1302      679     283
#    10911    13260     5975  ...     2523     1890     1706     1224     589
#    15807    13634     6231  ...     2549     1862     1711     1121     509
#
#             연도  월   일  요일  분기
# 분기
# ...

# %% [markdown]
# 2022년

# %%
df22
# Out:
#                날짜  호선      역명  구분  06시 이전  06시-07시  07시-08시  08시-09시  09시-10시  \
# 0      2022-01-01   1     서울역  하차     113      560      617      910     1232
# 1      2022-01-01   1     시청역  하차      31      195      224      380      283
# 2      2022-01-01   1     종각역  하차      33      136      199      334      489
# 3      2022-01-01   1   종로3가역  하차      43      139      124      272      414
# 4      2022-01-01   1   종로5가역  하차      14       80      137      239      374
# ...           ...  ..     ...  ..     ...      ...      ...      ...      ...
# 99535  2022-12-31   8  단대오거리역  하차      35      142      118      220      238
# 99536  2022-12-31   8     신흥역  하차      12       56       56      128      154
# 99537  2022-12-31   8     수진역  하차      16       81       64      104      141
# 99538  2022-12-31   8     모란역  하차      13      104       62      131      100
# 99539  2022-12-31   8    남위례역  하차      22       68       77      149      152
#
# ...

# %%
# 각 분기별로 시간대별 승차 데이터를 큰 값부터 작은 값 순서로 sorted
df22_sorted =  df22.groupby('분기').apply(lambda x: x.sort_values(by=['06시 이전', '06시-07시', '07시-08시', '08시-09시', '09시-10시', '10시-11시',
                                                                    '11시-12시', '12시-13시', '13시-14시', '14시-15시', '15시-16시', '16시-17시',
                                                                    '17시-18시', '18시-19시', '19시-20시', '20시-21시', '21시-22시', '22시-23시',
                                                                    '23시-24시', '24시 이후'], ascending=False))
df22_sorted.head()
# Out:
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_4672\1166967968.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df22_sorted =  df22.groupby('분기').apply(lambda x: x.sort_values(by=['06시 이전', '06시-07시', '07시-08시', '08시-09시', '09시-10시', '10시-11시',
#                   날짜  호선   역명  구분  06시 이전  06시-07시  07시-08시  08시-09시  09시-10시  \
# 분기
# 1  10385  2022-02-08   2  강남역  하차     473     1997     5863    13296    13946
#    6575   2022-01-25   2  강남역  하차     463     2007     6287    13633    14629
#    9297   2022-02-04   2  강남역  하차     461     1784     5461    12328    12557
#    4394   2022-01-17   2  강남역  하차     457     2012     6178    14118    14897
# ...

# %%
# index를 포함하지 않고 데이터 저장
df22_sorted.to_csv("2022 분기별 하차인원 sorted.csv", index=False)
df22_sorted.head()
# Out:
#                   날짜  호선   역명  구분  06시 이전  06시-07시  07시-08시  08시-09시  09시-10시  \
# 분기
# 1  10385  2022-02-08   2  강남역  하차     473     1997     5863    13296    13946
#    6575   2022-01-25   2  강남역  하차     463     2007     6287    13633    14629
#    9297   2022-02-04   2  강남역  하차     461     1784     5461    12328    12557
#    4394   2022-01-17   2  강남역  하차     457     2012     6178    14118    14897
#    24022  2022-03-30   2  강남역  하차     457     1772     5755    12828    11503
#
#           10시-11시  ...  20시-21시  21시-22시  22시-23시  23시-24시  24시 이후    연도  월  \
# 분기                 ...
# 1  10385     6034  ...     1281     1576      740      287     NaN  2022  2
#    6575      6259  ...     1422     1866      767      340     NaN  2022  1
#    9297      5547  ...     1312     1657      731      350     NaN  2022  2
#    4394      6295  ...     1493     1610      657      288     NaN  2022  1
#    24022     4907  ...     1346     1011      898      728     NaN  2022  3
#
# ...

# %% [markdown]
# 2021년

# %%
df21
# Out:
#                 날짜   호선      역명  구분  06시 이전  06시-07시  07시-08시  08시-09시  \
# 0       2021-01-01  1호선     서울역  하차      85      355      438      592
# 1       2021-01-01  1호선     시청역  하차      40      145      176      312
# 2       2021-01-01  1호선     종각역  하차      34      116      178      304
# 3       2021-01-01  1호선   종로3가역  하차      37       82       94      169
# 4       2021-01-01  1호선   종로5가역  하차      18       61      106      145
# ...            ...  ...     ...  ..     ...      ...      ...      ...
# 102182  2021-12-31  8호선  단대오거리역  하차      54      189      325      639
# 102183  2021-12-31  8호선     신흥역  하차      16       80      122      251
# 102184  2021-12-31  8호선     수진역  하차      25       75       96      340
# 102185  2021-12-31  8호선     모란역  하차      20       96      120      311
# 102186  2021-12-31  8호선    남위례역  하차      10       41      119      375
#
#         09시-10시  10시-11시  ...  19시-20시  20시-21시  21시-22시  22시-23시  23시-24시  \
# ...

# %%
# 각 분기별로 시간대별 승차 데이터를 큰 값부터 작은 값 순서로 sorted
df21_sorted =  df21.groupby('분기').apply(lambda x: x.sort_values(by=['06시 이전', '06시-07시', '07시-08시', '08시-09시', '09시-10시', '10시-11시',
                                                                    '11시-12시', '12시-13시', '13시-14시', '14시-15시', '15시-16시', '16시-17시',
                                                                    '17시-18시', '18시-19시', '19시-20시', '20시-21시', '21시-22시', '22시-23시',
                                                                    '23시-24시'], ascending=False))
df21_sorted.head()
# Out:
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_12800\3882441796.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df21_sorted =  df21.groupby('분기').apply(lambda x: x.sort_values(by=['06시 이전', '06시-07시', '07시-08시', '08시-09시', '09시-10시', '10시-11시',
#                   날짜   호선   역명  구분  06시 이전  06시-07시  07시-08시  08시-09시  \
# 분기
# 1  5023   2021-01-19  2호선  강남역  하차     485     1741     5917    12435
#    1695   2021-01-07  2호선  강남역  하차     484     1780     5466    11817
#    21400  2021-03-19  2호선  강남역  하차     482     1957     6359    13326
#    8909   2021-02-02  2호선  강남역  하차     479     1883     6004    13440
#    21122  2021-03-18  2호선  강남역  하차     478     2038     6390    14422
#
# ...

# %%
# index를 포함하지 않고 데이터 저장
df21_sorted.to_csv("2021 분기별 하차인원 sorted.csv", index=False)
df21_sorted.head()
# Out:
#                   날짜   호선   역명  구분  06시 이전  06시-07시  07시-08시  08시-09시  \
# 분기
# 1  5023   2021-01-19  2호선  강남역  하차     485     1741     5917    12435
#    1695   2021-01-07  2호선  강남역  하차     484     1780     5466    11817
#    21400  2021-03-19  2호선  강남역  하차     482     1957     6359    13326
#    8909   2021-02-02  2호선  강남역  하차     479     1883     6004    13440
#    21122  2021-03-18  2호선  강남역  하차     478     2038     6390    14422
#
#           09시-10시  10시-11시  ...  19시-20시  20시-21시  21시-22시  22시-23시  23시-24시  \
# 분기                          ...
# 1  5023     11901     5080  ...     2585     1176     1339      503      252
#    1695     10667     5787  ...     2182     1052     1054      446      193
#    21400    12967     5672  ...     5622     1818     1337     1987      633
#    8909     12641     5507  ...     2875     1322     1550      481      258
#    21122    12154     5784  ...     3838     1414     1217     1553      496
#
#             연도  월   일  요일  분기
# 분기
# ...

# %% [markdown]
# 2020년

# %%
df20
# Out:
#                 날짜   호선       역명  구분  06시 이전  06시-07시  07시-08시  08시-09시  \
# 0       2020-01-01  1호선      서울역  하차     235      952      828     1043
# 1       2020-01-01  1호선      시청역  하차      81      223      334      570
# 2       2020-01-01  1호선      종각역  하차      71      191      295      511
# 3       2020-01-01  1호선    종로3가역  하차      53      147      190      363
# 4       2020-01-01  1호선    종로5가역  하차      22      124      170      240
# ...            ...  ...      ...  ..     ...      ...      ...      ...
# 101135  2020-12-31  8호선  남한산성입구역  하차      47      128      296      672
# 101136  2020-12-31  8호선   단대오거리역  하차      70      205      308      520
# 101137  2020-12-31  8호선      신흥역  하차      31       95       78      211
# 101138  2020-12-31  8호선      수진역  하차      15       70       92      227
# 101139  2020-12-31  8호선      모란역  하차      15       59      111      181
#
#         09시-10시  10시-11시  ...  20시-21시  21시-22시  22시-23시  23시-24시  24시 이후  \
# ...

# %%
# 각 분기별로 시간대별 승차 데이터를 큰 값부터 작은 값 순서로 sorted
df20_sorted =  df20.groupby('분기').apply(lambda x: x.sort_values(by=['06시 이전', '06시-07시', '07시-08시', '08시-09시', '09시-10시', '10시-11시',
                                                                    '11시-12시', '12시-13시', '13시-14시', '14시-15시', '15시-16시', '16시-17시',
                                                                    '17시-18시', '18시-19시', '19시-20시', '20시-21시', '21시-22시', '22시-23시',
                                                                    '23시-24시', '24시 이후'], ascending=False))
df20_sorted.head()
# Out:
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_4672\1290076512.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df20_sorted =  df20.groupby('분기').apply(lambda x: x.sort_values(by=['06시 이전', '06시-07시', '07시-08시', '08시-09시', '09시-10시', '10시-11시',
#                  날짜   호선   역명  구분  06시 이전  06시-07시  07시-08시  08시-09시  09시-10시  \
# 분기
# 1  7746  2020-01-29  2호선  강남역  하차     581     2208     7228    15862    16857
#    3339  2020-01-13  2호선  강남역  하차     575     2502     7858    16310    18269
#    8299  2020-01-31  2호선  강남역  하차     575     2110     6764    16050    16455
#    4167  2020-01-16  2호선  강남역  하차     571     2403     7290    16605    17882
# ...

# %%
# index를 포함하지 않고 데이터 저장
df20_sorted.to_csv("2020 분기별 하차인원 sorted.csv", index=False)
df20_sorted.head()
# Out:
#                  날짜   호선   역명  구분  06시 이전  06시-07시  07시-08시  08시-09시  09시-10시  \
# 분기
# 1  7746  2020-01-29  2호선  강남역  하차     581     2208     7228    15862    16857
#    3339  2020-01-13  2호선  강남역  하차     575     2502     7858    16310    18269
#    8299  2020-01-31  2호선  강남역  하차     575     2110     6764    16050    16455
#    4167  2020-01-16  2호선  강남역  하차     571     2403     7290    16605    17882
#    5820  2020-01-22  2호선  강남역  하차     571     2309     7348    16282    17386
#
#          10시-11시  ...  20시-21시  21시-22시  22시-23시  23시-24시  24시 이후    연도  월  \
# 분기                ...
# 1  7746     6927  ...     2646     1947     1709      997     408  2020  1
#    3339     7318  ...     2712     2014     1809      885     420  2020  1
#    8299     6705  ...     3212     2361     1926     1465     650  2020  1
#    4167     7517  ...     3182     2288     2434     1254     474  2020  1
#    5820     7531  ...     3202     2426     1820     1230     623  2020  1
#
# ...

# %% [markdown]
# 2019년

# %%
df19
# Out:
#                 날짜   호선       역명  구분  06시 이전  06시-07시  07시-08시  08시-09시  \
# 0       2019-01-01  1호선      서울역  하차     222      821      808      961
# 1       2019-01-01  1호선      시청역  하차      48      237      323      571
# 2       2019-01-01  1호선      종각역  하차      68      179      293      546
# 3       2019-01-01  1호선    종로3가역  하차      38      180      261      424
# 4       2019-01-01  1호선    종로5가역  하차      25      102      140      296
# ...            ...  ...      ...  ..     ...      ...      ...      ...
# 100397  2019-12-31  8호선  남한산성입구역  하차      45      161      392      800
# 100398  2019-12-31  8호선   단대오거리역  하차      54      178      369      713
# 100399  2019-12-31  8호선      신흥역  하차      20       87       86      243
# 100400  2019-12-31  8호선      수진역  하차      27       97      115      433
# 100401  2019-12-31  8호선      모란역  하차      15       99      140      386
#
#         09시-10시  10시-11시  ...  20시-21시  21시-22시  22시-23시  23시-24시  24시 이후  \
# ...

# %%
# 각 분기별로 시간대별 승차 데이터를 큰 값부터 작은 값 순서로 sorted
df19_sorted =  df19.groupby('분기').apply(lambda x: x.sort_values(by=['06시 이전', '06시-07시', '07시-08시', '08시-09시', '09시-10시', '10시-11시',
                                                                    '11시-12시', '12시-13시', '13시-14시', '14시-15시', '15시-16시', '16시-17시',
                                                                    '17시-18시', '18시-19시', '19시-20시', '20시-21시', '21시-22시', '22시-23시',
                                                                    '23시-24시', '24시 이후'], ascending=False))
df19_sorted.head()
# Out:
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_4672\291862619.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df19_sorted =  df19.groupby('분기').apply(lambda x: x.sort_values(by=['06시 이전', '06시-07시', '07시-08시', '08시-09시', '09시-10시', '10시-11시',
#                   날짜   호선   역명  구분  06시 이전  06시-07시  07시-08시  08시-09시  \
# 분기
# 1  11306  2019-02-11  2호선  강남역  하차     563     2469     8120    15743
#    20931  2019-03-18  2호선  강남역  하차     557     2440     8624    16668
#    12406  2019-02-15  2호선  강남역  하차     551     2218     6875    15387
#    19006  2019-03-11  2호선  강남역  하차     549     2547     8928    16833
#    22856  2019-03-25  2호선  강남역  하차     548     2498     8714    15933
#
# ...

# %%
# index를 포함하지 않고 데이터 저장
df19_sorted.to_csv("2019 분기별 하차인원 sorted.csv", index=False)
df19_sorted.head()
# Out:
#                   날짜   호선   역명  구분  06시 이전  06시-07시  07시-08시  08시-09시  \
# 분기
# 1  11306  2019-02-11  2호선  강남역  하차     563     2469     8120    15743
#    20931  2019-03-18  2호선  강남역  하차     557     2440     8624    16668
#    12406  2019-02-15  2호선  강남역  하차     551     2218     6875    15387
#    19006  2019-03-11  2호선  강남역  하차     549     2547     8928    16833
#    22856  2019-03-25  2호선  강남역  하차     548     2498     8714    15933
#
#           09시-10시  10시-11시  ...  20시-21시  21시-22시  22시-23시  23시-24시  24시 이후  \
# 분기                          ...
# 1  11306    18402     7135  ...     3187     2169     1813     1023     391
#    20931    15851     6493  ...     2859     2085     1850      942     384
#    12406    17225     7885  ...     4244     3029     2618     1786     942
#    19006    15918     6960  ...     2831     1986     1619      869     396
#    22856    15989     6605  ...     2678     2111     1689      938     405
#
#             연도  월   일  요일  분기
# 분기
# ...

# %% [markdown]
# 2018년

# %%
df18
# Out:
#                 날짜   호선       역명  구분  06시 이전  06시-07시  07시-08시  08시-09시  \
# 0       2018-01-01  1호선      서울역  하차     205     1040      872      984
# 1       2018-01-01  1호선      시청역  하차      47      294      497     1017
# 2       2018-01-01  1호선      종각역  하차      74      219      327      606
# 3       2018-01-01  1호선    종로3가역  하차      48      128      165      348
# 4       2018-01-01  1호선    종로5가역  하차      33       83      145      340
# ...            ...  ...      ...  ..     ...      ...      ...      ...
# 100370  2018-12-31  8호선  남한산성입구역  하차      40      136      303      735
# 100371  2018-12-31  8호선   단대오거리역  하차      50      167      332      636
# 100372  2018-12-31  8호선      신흥역  하차      20       83       92      194
# 100373  2018-12-31  8호선      수진역  하차      18       91      136      356
# 100374  2018-12-31  8호선      모란역  하차      15       87      133      329
#
#         09시-10시  10시-11시  ...  20시-21시  21시-22시  22시-23시  23시-24시  24시 이후  \
# ...

# %%
# 각 분기별로 시간대별 승차 데이터를 큰 값부터 작은 값 순서로 sorted
df18_sorted =  df18.groupby('분기').apply(lambda x: x.sort_values(by=['06시 이전', '06시-07시', '07시-08시', '08시-09시', '09시-10시', '10시-11시',
                                                                    '11시-12시', '12시-13시', '13시-14시', '14시-15시', '15시-16시', '16시-17시',
                                                                    '17시-18시', '18시-19시', '19시-20시', '20시-21시', '21시-22시', '22시-23시',
                                                                    '23시-24시', '24시 이후'], ascending=False))
df18_sorted.head()
# Out:
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_452\2434452343.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df18_sorted =  df18.groupby('분기').apply(lambda x: x.sort_values(by=['06시 이전', '06시-07시', '07시-08시', '08시-09시', '09시-10시', '10시-11시',
#                   날짜   호선   역명  구분  06시 이전  06시-07시  07시-08시  08시-09시  \
# 분기
# 1  17565  2018-03-12  2호선  강남역  하차     549     2645     9571    17007
#    1221   2018-01-11  2호선  강남역  하차     530     2307     7770    16692
#    11531  2018-02-26  2호선  강남역  하차     529     2430     8622    16588
#    1935   2018-01-17  2호선  강남역  하차     529     2368     8009    16485
#    16732  2018-03-05  2호선  강남역  하차     528     2531     8902    16438
#
# ...

# %%
# index를 포함하지 않고 데이터 저장
df18_sorted.to_csv("2018 분기별 하차인원 sorted.csv", index=False)
df18_sorted.head()
# Out:
#                   날짜   호선   역명  구분  06시 이전  06시-07시  07시-08시  08시-09시  \
# 분기
# 1  17565  2018-03-12  2호선  강남역  하차     549     2645     9571    17007
#    1221   2018-01-11  2호선  강남역  하차     530     2307     7770    16692
#    11531  2018-02-26  2호선  강남역  하차     529     2430     8622    16588
#    1935   2018-01-17  2호선  강남역  하차     529     2368     8009    16485
#    16732  2018-03-05  2호선  강남역  하차     528     2531     8902    16438
#
#           09시-10시  10시-11시  ...  20시-21시  21시-22시  22시-23시  23시-24시  24시 이후  \
# 분기                          ...
# 1  17565    14383     7358  ...     3112     2154     1842      877     376
#    1221     16084     7177  ...     2939     2204     2123     1143     431
#    11531    14709     7039  ...     3296     2492     1940      937     430
#    1935     17476     7429  ...     3102     2256     1953     1107     433
#    16732    15391     6830  ...     3111     2261     1830      951     382
#
#             연도  월   일  요일  분기
# 분기
# ...
