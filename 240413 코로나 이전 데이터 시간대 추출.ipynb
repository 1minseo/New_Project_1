# %%
import pandas as pd
import numpy as np

# %%
# 코로나 이전 데이터 불러오기
df = pd.read_csv("./코로나 이전 승하차인원.csv")

# %%
df.head()
# Out:
#            날짜       역명  구분  06시 이전  06시-07시  07시-08시  08시-09시  09시-10시  \
# 0  2018-01-01  1호선 서울역  승차     373      318      365      785     1047
# 1  2018-01-01  1호선 서울역  하차     205     1040      872      984     1650
# 2  2018-01-01  1호선 시청역  승차      87      105      124      197      291
# 3  2018-01-01  1호선 시청역  하차      47      294      497     1017      673
# 4  2018-01-01  1호선 종각역  승차     604      399      191      250      370
#
#    10시-11시  11시-12시  ...  월  일  요일  분기         역전화번호  \
# 0     1576     2510  ...  1  1   월   1  02-6110-1331
# 1     1743     2175  ...  1  1   월   1  02-6110-1331
# 2      499      722  ...  1  1   월   1  02-6110-1321
# 3      657      820  ...  1  1   월   1  02-6110-1321
# 4      439      705  ...  1  1   월   1  02-6110-1311
#
#                         도로명주소                           지번주소     행정동  \
# 0  서울특별시 중구 세종대로 지하2(남대문로 5가)  서울특별시 중구 남대문로5가 73-6 서울역(1호선)  남대문로5가
# 1  서울특별시 중구 세종대로 지하2(남대문로 5가)  서울특별시 중구 남대문로5가 73-6 서울역(1호선)  남대문로5가
# ...

# %%
def categorize_weekday(요일):
    if 요일 in ['월', '화', '수', '목', '금']:
        return '평일'
    else:
        return '주말'
    
# '주간' 컬럼 생성
df['주간'] = df['요일'].apply(categorize_weekday)

# %%
df.head()
# Out:
#            날짜       역명  구분  06시 이전  06시-07시  07시-08시  08시-09시  09시-10시  \
# 0  2018-01-01  1호선 서울역  승차     373      318      365      785     1047
# 1  2018-01-01  1호선 서울역  하차     205     1040      872      984     1650
# 2  2018-01-01  1호선 시청역  승차      87      105      124      197      291
# 3  2018-01-01  1호선 시청역  하차      47      294      497     1017      673
# 4  2018-01-01  1호선 종각역  승차     604      399      191      250      370
#
#    10시-11시  11시-12시  ...  일  요일  분기         역전화번호                       도로명주소  \
# 0     1576     2510  ...  1   월   1  02-6110-1331  서울특별시 중구 세종대로 지하2(남대문로 5가)
# 1     1743     2175  ...  1   월   1  02-6110-1331  서울특별시 중구 세종대로 지하2(남대문로 5가)
# 2      499      722  ...  1   월   1  02-6110-1321     서울특별시 중구 세종대로 지하101(정동)
# 3      657      820  ...  1   월   1  02-6110-1321     서울특별시 중구 세종대로 지하101(정동)
# 4      439      705  ...  1   월   1  02-6110-1311     서울특별시 종로구 종로 지하55(종로1가)
#
#                             지번주소     행정동         위도          경도  주간
# ...

# %% [markdown]
# 평일 데이터 추출

# %%
filtered_df = df[df['요일'].astype(str).str.contains('월|화|수|목|금')]
print(filtered_df)
# Out:
#                 날짜       역명  구분  06시 이전  06시-07시  07시-08시  08시-09시  09시-10시  \
# 0       2018-01-01  1호선 서울역  승차     373      318      365      785     1047
# 1       2018-01-01  1호선 서울역  하차     205     1040      872      984     1650
# 2       2018-01-01  1호선 시청역  승차      87      105      124      197      291
# 3       2018-01-01  1호선 시청역  하차      47      294      497     1017      673
# 4       2018-01-01  1호선 종각역  승차     604      399      191      250      370
# ...            ...      ...  ..     ...      ...      ...      ...      ...
# 417221  2020-03-31  8호선 문정역  하차     106      385     1679     6290     3496
# 417222  2020-03-31  8호선 장지역  승차     146      493     1703     1975     1033
# 417223  2020-03-31  8호선 장지역  하차      70      276      668     1681     1266
# 417224  2020-03-31  8호선 복정역  승차     121      359     1116     1547      787
# 417225  2020-03-31  8호선 복정역  하차      67      307      389      681      336
#
# ...

# %%
# 코로나 이전 평일 출근시간대 추출
weekday_1 = filtered_df[['날짜', '역명', '구분', '07시-08시', '08시-09시', '09시-10시', '연도', '월', '일', '요일',
                         '분기', '역전화번호', '도로명주소', '지번주소', '행정동', '위도', '경도', '주간']]
weekday_1.head()
# Out:
#            날짜       역명  구분  07시-08시  08시-09시  09시-10시    연도  월  일 요일  분기  \
# 0  2018-01-01  1호선 서울역  승차      365      785     1047  2018  1  1  월   1
# 1  2018-01-01  1호선 서울역  하차      872      984     1650  2018  1  1  월   1
# 2  2018-01-01  1호선 시청역  승차      124      197      291  2018  1  1  월   1
# 3  2018-01-01  1호선 시청역  하차      497     1017      673  2018  1  1  월   1
# 4  2018-01-01  1호선 종각역  승차      191      250      370  2018  1  1  월   1
#
#           역전화번호                       도로명주소                           지번주소  \
# 0  02-6110-1331  서울특별시 중구 세종대로 지하2(남대문로 5가)  서울특별시 중구 남대문로5가 73-6 서울역(1호선)
# 1  02-6110-1331  서울특별시 중구 세종대로 지하2(남대문로 5가)  서울특별시 중구 남대문로5가 73-6 서울역(1호선)
# 2  02-6110-1321     서울특별시 중구 세종대로 지하101(정동)       서울특별시 중구 정동 5-5 시청역(1호선)
# 3  02-6110-1321     서울특별시 중구 세종대로 지하101(정동)       서울특별시 중구 정동 5-5 시청역(1호선)
# 4  02-6110-1311     서울특별시 종로구 종로 지하55(종로1가)     서울특별시 종로구 종로1가 54 종각역(1호선)
#
#       행정동         위도          경도  주간
# 0  남대문로5가  37.553150  126.972533  평일
# ...

# %%
# index를 포함하지 않고 데이터 저장
weekday_1.to_csv("코로나 이전 평일 출근시간대 승하차인원.csv", index=False)

# %%
# 코로나 이전 평일 낮 시간대 추출
weekday_2 = filtered_df[['날짜', '역명', '구분', '11시-12시', '12시-13시', '13시-14시', '14시-15시', '15시-16시', '연도', '월', '일',
                         '요일', '분기', '역전화번호', '도로명주소', '지번주소', '행정동', '위도', '경도', '주간']]
weekday_2.head()
# Out:
#            날짜       역명  구분  11시-12시  12시-13시  13시-14시  14시-15시  15시-16시    연도  \
# 0  2018-01-01  1호선 서울역  승차     2510     3233     3145     2443     2980  2018
# 1  2018-01-01  1호선 서울역  하차     2175     2991     2877     2743     2687  2018
# 2  2018-01-01  1호선 시청역  승차      722      612      580      821      907  2018
# 3  2018-01-01  1호선 시청역  하차      820      958     1009      877      830  2018
# 4  2018-01-01  1호선 종각역  승차      705      980     1153     1392     1710  2018
#
#    월  일 요일  분기         역전화번호                       도로명주소  \
# 0  1  1  월   1  02-6110-1331  서울특별시 중구 세종대로 지하2(남대문로 5가)
# 1  1  1  월   1  02-6110-1331  서울특별시 중구 세종대로 지하2(남대문로 5가)
# 2  1  1  월   1  02-6110-1321     서울특별시 중구 세종대로 지하101(정동)
# 3  1  1  월   1  02-6110-1321     서울특별시 중구 세종대로 지하101(정동)
# 4  1  1  월   1  02-6110-1311     서울특별시 종로구 종로 지하55(종로1가)
#
#                             지번주소     행정동         위도          경도  주간
# 0  서울특별시 중구 남대문로5가 73-6 서울역(1호선)  남대문로5가  37.553150  126.972533  평일
# ...

# %%
# index를 포함하지 않고 데이터 저장
weekday_2.to_csv("코로나 이전 평일 낮 시간대 승하차인원.csv", index=False)

# %%
# 코로나 이전 평일 퇴근시간대 추출
weekday_3 = filtered_df[['날짜', '역명', '구분', '17시-18시', '18시-19시', '19시-20시', '연도', '월', '일', '요일',
                         '분기', '역전화번호', '도로명주소', '지번주소', '행정동', '위도', '경도', '주간']]
weekday_3.head()
# Out:
#            날짜       역명  구분  17시-18시  18시-19시  19시-20시    연도  월  일 요일  분기  \
# 0  2018-01-01  1호선 서울역  승차     3891     3227     2945  2018  1  1  월   1
# 1  2018-01-01  1호선 서울역  하차     2845     2337     2131  2018  1  1  월   1
# 2  2018-01-01  1호선 시청역  승차     1102     1278     1163  2018  1  1  월   1
# 3  2018-01-01  1호선 시청역  하차      702      552      388  2018  1  1  월   1
# 4  2018-01-01  1호선 종각역  승차     2172     2171     1873  2018  1  1  월   1
#
#           역전화번호                       도로명주소                           지번주소  \
# 0  02-6110-1331  서울특별시 중구 세종대로 지하2(남대문로 5가)  서울특별시 중구 남대문로5가 73-6 서울역(1호선)
# 1  02-6110-1331  서울특별시 중구 세종대로 지하2(남대문로 5가)  서울특별시 중구 남대문로5가 73-6 서울역(1호선)
# 2  02-6110-1321     서울특별시 중구 세종대로 지하101(정동)       서울특별시 중구 정동 5-5 시청역(1호선)
# 3  02-6110-1321     서울특별시 중구 세종대로 지하101(정동)       서울특별시 중구 정동 5-5 시청역(1호선)
# 4  02-6110-1311     서울특별시 종로구 종로 지하55(종로1가)     서울특별시 종로구 종로1가 54 종각역(1호선)
#
#       행정동         위도          경도  주간
# 0  남대문로5가  37.553150  126.972533  평일
# ...

# %%
# index를 포함하지 않고 데이터 저장
weekday_3.to_csv("코로나 이전 평일 퇴근시간대 승하차인원.csv", index=False)

# %%
# 코로나 이전 평일 야간시간대 추출
weekday_4 = filtered_df[['날짜', '역명', '구분', '22시-23시', '23시-24시', '24시 이후', '연도', '월', '일',
                         '요일', '분기', '역전화번호', '도로명주소', '지번주소', '행정동', '위도', '경도', '주간']]
weekday_4.head()
# Out:
#            날짜       역명  구분  22시-23시  23시-24시  24시 이후    연도  월  일 요일  분기  \
# 0  2018-01-01  1호선 서울역  승차     1750      781      96  2018  1  1  월   1
# 1  2018-01-01  1호선 서울역  하차      868      477     147  2018  1  1  월   1
# 2  2018-01-01  1호선 시청역  승차      553      214       9  2018  1  1  월   1
# 3  2018-01-01  1호선 시청역  하차      160      100      39  2018  1  1  월   1
# 4  2018-01-01  1호선 종각역  승차     1458      580      28  2018  1  1  월   1
#
#           역전화번호                       도로명주소                           지번주소  \
# 0  02-6110-1331  서울특별시 중구 세종대로 지하2(남대문로 5가)  서울특별시 중구 남대문로5가 73-6 서울역(1호선)
# 1  02-6110-1331  서울특별시 중구 세종대로 지하2(남대문로 5가)  서울특별시 중구 남대문로5가 73-6 서울역(1호선)
# 2  02-6110-1321     서울특별시 중구 세종대로 지하101(정동)       서울특별시 중구 정동 5-5 시청역(1호선)
# 3  02-6110-1321     서울특별시 중구 세종대로 지하101(정동)       서울특별시 중구 정동 5-5 시청역(1호선)
# 4  02-6110-1311     서울특별시 종로구 종로 지하55(종로1가)     서울특별시 종로구 종로1가 54 종각역(1호선)
#
#       행정동         위도          경도  주간
# 0  남대문로5가  37.553150  126.972533  평일
# ...

# %%
# index를 포함하지 않고 데이터 저장
weekday_4.to_csv("코로나 이전 평일 야간시간대 승하차인원.csv", index=False)

# %% [markdown]
# 주말 데이터 추출

# %%
df.head()
# Out:
#            날짜       역명  구분  06시 이전  06시-07시  07시-08시  08시-09시  09시-10시  \
# 0  2018-01-01  1호선 서울역  승차     373      318      365      785     1047
# 1  2018-01-01  1호선 서울역  하차     205     1040      872      984     1650
# 2  2018-01-01  1호선 시청역  승차      87      105      124      197      291
# 3  2018-01-01  1호선 시청역  하차      47      294      497     1017      673
# 4  2018-01-01  1호선 종각역  승차     604      399      191      250      370
#
#    10시-11시  11시-12시  ...  일  요일  분기         역전화번호                       도로명주소  \
# 0     1576     2510  ...  1   월   1  02-6110-1331  서울특별시 중구 세종대로 지하2(남대문로 5가)
# 1     1743     2175  ...  1   월   1  02-6110-1331  서울특별시 중구 세종대로 지하2(남대문로 5가)
# 2      499      722  ...  1   월   1  02-6110-1321     서울특별시 중구 세종대로 지하101(정동)
# 3      657      820  ...  1   월   1  02-6110-1321     서울특별시 중구 세종대로 지하101(정동)
# 4      439      705  ...  1   월   1  02-6110-1311     서울특별시 종로구 종로 지하55(종로1가)
#
#                             지번주소     행정동         위도          경도  주간
# ...

# %%
# '요일' 컬럼에서 '토', '일' 데이터 추출
filtered_df_1 = df[df['요일'].astype(str).str.contains('토|일')]
print(filtered_df_1)
# Out:
#                 날짜       역명  구분  06시 이전  06시-07시  07시-08시  08시-09시  09시-10시  \
# 1170    2018-01-06  1호선 서울역  승차     441      366      513     1279     1511
# 1171    2018-01-06  1호선 서울역  하차     178     1226     1651     1941     2916
# 1172    2018-01-06  1호선 시청역  승차      68       83      164      220      355
# 1173    2018-01-06  1호선 시청역  하차      54      486      531      970     1243
# 1174    2018-01-06  1호선 종각역  승차     233      190      168      284      356
# ...            ...      ...  ..     ...      ...      ...      ...      ...
# 416205  2020-03-29  8호선 문정역  하차      11       88      158      159      214
# 416206  2020-03-29  8호선 장지역  승차      81      101      193      265      299
# 416207  2020-03-29  8호선 장지역  하차      33      135      169      339      448
# 416208  2020-03-29  8호선 복정역  승차      52       84      129      160      254
# 416209  2020-03-29  8호선 복정역  하차      31       94      100      124      129
#
# ...

# %%
# 코로나 이전 주말 오전시간대 추출
weekend_1 = filtered_df_1[['날짜', '역명', '구분', '06시 이전', '06시-07시', '07시-08시', '08시-09시', '09시-10시', '10시-11시', '연도',
                           '월', '일', '요일', '분기', '역전화번호', '도로명주소', '지번주소', '행정동', '위도', '경도', '주간']]
weekend_1.head()
# Out:
#               날짜       역명  구분  06시 이전  06시-07시  07시-08시  08시-09시  09시-10시  \
# 1170  2018-01-06  1호선 서울역  승차     441      366      513     1279     1511
# 1171  2018-01-06  1호선 서울역  하차     178     1226     1651     1941     2916
# 1172  2018-01-06  1호선 시청역  승차      68       83      164      220      355
# 1173  2018-01-06  1호선 시청역  하차      54      486      531      970     1243
# 1174  2018-01-06  1호선 종각역  승차     233      190      168      284      356
#
#       10시-11시    연도  ...  일  요일 분기         역전화번호                       도로명주소  \
# 1170     2007  2018  ...  6   토  1  02-6110-1331  서울특별시 중구 세종대로 지하2(남대문로 5가)
# 1171     2846  2018  ...  6   토  1  02-6110-1331  서울특별시 중구 세종대로 지하2(남대문로 5가)
# 1172      379  2018  ...  6   토  1  02-6110-1321     서울특별시 중구 세종대로 지하101(정동)
# 1173     1154  2018  ...  6   토  1  02-6110-1321     서울특별시 중구 세종대로 지하101(정동)
# 1174      555  2018  ...  6   토  1  02-6110-1311     서울특별시 종로구 종로 지하55(종로1가)
#
# ...

# %%
# index를 포함하지 않고 데이터 저장
weekend_1.to_csv("코로나 이전 주말 오전시간대 승하차인원.csv", index=False)

# %%
# 코로나 이전 주말 오후시간대 추출
weekend_2 = filtered_df_1[['날짜', '역명', '구분', '11시-12시', '12시-13시', '13시-14시', '14시-15시', '15시-16시', '16시-17시', '17시-18시',
                           '18시-19시', '19시-20시', '20시-21시', '21시-22시', '22시-23시', '23시-24시', '24시 이후', '연도',
                           '월', '일', '요일', '분기', '역전화번호', '도로명주소', '지번주소', '행정동', '위도', '경도', '주간']]
weekend_2.head()
# Out:
#               날짜       역명  구분  11시-12시  12시-13시  13시-14시  14시-15시  15시-16시  \
# 1170  2018-01-06  1호선 서울역  승차     3268     3985     3818     3058     3646
# 1171  2018-01-06  1호선 서울역  하차     2726     3236     3239     3024     3387
# 1172  2018-01-06  1호선 시청역  승차      490      728      800     1360     1710
# 1173  2018-01-06  1호선 시청역  하차     1433     1590     2038     1870     1388
# 1174  2018-01-06  1호선 종각역  승차      894     1259     1812     2261     2582
#
#       16시-17시  17시-18시  ...  일  요일  분기         역전화번호  \
# 1170     4233     3845  ...  6   토   1  02-6110-1331
# 1171     3331     3201  ...  6   토   1  02-6110-1331
# 1172     2033     2087  ...  6   토   1  02-6110-1321
# 1173     1275     1154  ...  6   토   1  02-6110-1321
# 1174     3422     3541  ...  6   토   1  02-6110-1311
#
#                            도로명주소                           지번주소     행정동  \
# 1170  서울특별시 중구 세종대로 지하2(남대문로 5가)  서울특별시 중구 남대문로5가 73-6 서울역(1호선)  남대문로5가
# ...

# %%
# index를 포함하지 않고 데이터 저장
weekend_2.to_csv("코로나 이전 주말 오후시간대 승하차인원.csv", index=False)
