# %%
import pandas as pd
import numpy as np

# %%
# 코로나 이후 데이터 불러오기
df = pd.read_csv("./코로나 이후 승하차인원.csv")

# %%
df.head()
# Out:
#            날짜       역명  구분  06시 이전  06시-07시  07시-08시  08시-09시  09시-10시  \
# 0  2022-04-01  1호선 서울역  승차     315      369     1334     2085     1509
# 1  2022-04-01  1호선 서울역  하차     200     1276     3370     7239     4347
# 2  2022-04-01  1호선 시청역  승차      78      115      238      292      292
# 3  2022-04-01  1호선 시청역  하차     192      658     2391     7239     2957
# 4  2022-04-01  1호선 종각역  승차      80      110      210      329      390
#
#    10시-11시  11시-12시  ...  월  일  요일  분기         역전화번호  \
# 0     1361     1696  ...  4  1   금   2  02-6110-1331
# 1     2056     1790  ...  4  1   금   2  02-6110-1331
# 2      391      493  ...  4  1   금   2  02-6110-1321
# 3     1059      951  ...  4  1   금   2  02-6110-1321
# 4      587      891  ...  4  1   금   2  02-6110-1311
#
#                         도로명주소                           지번주소     행정동  \
# 0  서울특별시 중구 세종대로 지하2(남대문로 5가)  서울특별시 중구 남대문로5가 73-6 서울역(1호선)  남대문로5가
# 1  서울특별시 중구 세종대로 지하2(남대문로 5가)  서울특별시 중구 남대문로5가 73-6 서울역(1호선)  남대문로5가
# ...

# %%
def categorize_weekday(요일):
    if 요일 in ['월', '화', '수', '목', '금']:
        return '평일'
    else:
        return '주말'
    
# '주간' 컬럼 생성
df['주간'] = df['요일'].apply(categorize_weekday)

# %%
df.head()
# Out:
#            날짜       역명  구분  06시 이전  06시-07시  07시-08시  08시-09시  09시-10시  \
# 0  2022-04-01  1호선 서울역  승차     315      369     1334     2085     1509
# 1  2022-04-01  1호선 서울역  하차     200     1276     3370     7239     4347
# 2  2022-04-01  1호선 시청역  승차      78      115      238      292      292
# 3  2022-04-01  1호선 시청역  하차     192      658     2391     7239     2957
# 4  2022-04-01  1호선 종각역  승차      80      110      210      329      390
#
#    10시-11시  11시-12시  ...  일  요일  분기         역전화번호                       도로명주소  \
# 0     1361     1696  ...  1   금   2  02-6110-1331  서울특별시 중구 세종대로 지하2(남대문로 5가)
# 1     2056     1790  ...  1   금   2  02-6110-1331  서울특별시 중구 세종대로 지하2(남대문로 5가)
# 2      391      493  ...  1   금   2  02-6110-1321     서울특별시 중구 세종대로 지하101(정동)
# 3     1059      951  ...  1   금   2  02-6110-1321     서울특별시 중구 세종대로 지하101(정동)
# 4      587      891  ...  1   금   2  02-6110-1311     서울특별시 종로구 종로 지하55(종로1가)
#
#                             지번주소     행정동         위도          경도  주간
# ...

# %% [markdown]
# 평일 데이터 추출

# %%
filtered_df = df[df['요일'].astype(str).str.contains('월|화|수|목|금')]
print(filtered_df)
# Out:
#                 날짜       역명  구분  06시 이전  06시-07시  07시-08시  08시-09시  09시-10시  \
# 0       2022-04-01  1호선 서울역  승차     315      369     1334     2085     1509
# 1       2022-04-01  1호선 서울역  하차     200     1276     3370     7239     4347
# 2       2022-04-01  1호선 시청역  승차      78      115      238      292      292
# 3       2022-04-01  1호선 시청역  하차     192      658     2391     7239     2957
# 4       2022-04-01  1호선 종각역  승차      80      110      210      329      390
# ...            ...      ...  ..     ...      ...      ...      ...      ...
# 342777  2024-01-31  8호선 문정역  하차     156      550     2598     8411     3505
# 342778  2024-01-31  8호선 장지역  승차     191      666     2058     2431     1272
# 342779  2024-01-31  8호선 장지역  하차     106      489     1111     1997     1161
# 342780  2024-01-31  8호선 복정역  승차     122      387     1238     1627      824
# 342781  2024-01-31  8호선 복정역  하차      84      312      452      661      338
#
# ...

# %%
# 코로나 이후 평일 출근시간대 추출
weekday_1 = filtered_df[['날짜', '역명', '구분', '07시-08시', '08시-09시', '연도', '월', '일', '요일', '분기', '역전화번호', '도로명주소', '지번주소', '행정동', '위도', '경도', '주간']]
weekday_1.head()
# Out:
#            날짜       역명  구분  07시-08시  08시-09시    연도  월  일 요일  분기         역전화번호  \
# 0  2022-04-01  1호선 서울역  승차     1334     2085  2022  4  1  금   2  02-6110-1331
# 1  2022-04-01  1호선 서울역  하차     3370     7239  2022  4  1  금   2  02-6110-1331
# 2  2022-04-01  1호선 시청역  승차      238      292  2022  4  1  금   2  02-6110-1321
# 3  2022-04-01  1호선 시청역  하차     2391     7239  2022  4  1  금   2  02-6110-1321
# 4  2022-04-01  1호선 종각역  승차      210      329  2022  4  1  금   2  02-6110-1311
#
#                         도로명주소                           지번주소     행정동  \
# 0  서울특별시 중구 세종대로 지하2(남대문로 5가)  서울특별시 중구 남대문로5가 73-6 서울역(1호선)  남대문로5가
# 1  서울특별시 중구 세종대로 지하2(남대문로 5가)  서울특별시 중구 남대문로5가 73-6 서울역(1호선)  남대문로5가
# 2     서울특별시 중구 세종대로 지하101(정동)       서울특별시 중구 정동 5-5 시청역(1호선)      정동
# 3     서울특별시 중구 세종대로 지하101(정동)       서울특별시 중구 정동 5-5 시청역(1호선)      정동
# 4     서울특별시 종로구 종로 지하55(종로1가)     서울특별시 종로구 종로1가 54 종각역(1호선)    종로1가
#
#           위도          경도  주간
# 0  37.553150  126.972533  평일
# ...

# %%
# index를 포함하지 않고 데이터 저장
weekday_1.to_csv("코로나 이후 평일 출근시간대 승하차인원.csv", index=False)

# %%
# 코로나 이후 평일 낮 시간대 추출
weekday_2 = filtered_df[['날짜', '역명', '구분', '11시-12시', '12시-13시', '13시-14시', '14시-15시', '연도', '월', '일', '요일', '분기', '역전화번호', '도로명주소', '지번주소', '행정동', '위도', '경도', '주간']]
weekday_2.head()
# Out:
#            날짜       역명  구분  11시-12시  12시-13시  13시-14시  14시-15시    연도  월  일 요일  \
# 0  2022-04-01  1호선 서울역  승차     1696     1869     2091     1830  2022  4  1  금
# 1  2022-04-01  1호선 서울역  하차     1790     1778     2106     1949  2022  4  1  금
# 2  2022-04-01  1호선 시청역  승차      493      597      737     1017  2022  4  1  금
# 3  2022-04-01  1호선 시청역  하차      951      822      836      669  2022  4  1  금
# 4  2022-04-01  1호선 종각역  승차      891     1028     1258     1599  2022  4  1  금
#
#    분기         역전화번호                       도로명주소  \
# 0   2  02-6110-1331  서울특별시 중구 세종대로 지하2(남대문로 5가)
# 1   2  02-6110-1331  서울특별시 중구 세종대로 지하2(남대문로 5가)
# 2   2  02-6110-1321     서울특별시 중구 세종대로 지하101(정동)
# 3   2  02-6110-1321     서울특별시 중구 세종대로 지하101(정동)
# 4   2  02-6110-1311     서울특별시 종로구 종로 지하55(종로1가)
#
#                             지번주소     행정동         위도          경도  주간
# 0  서울특별시 중구 남대문로5가 73-6 서울역(1호선)  남대문로5가  37.553150  126.972533  평일
# 1  서울특별시 중구 남대문로5가 73-6 서울역(1호선)  남대문로5가  37.553150  126.972533  평일
# ...

# %%
# index를 포함하지 않고 데이터 저장
weekday_2.to_csv("코로나 이후 평일 낮 시간대 승하차인원.csv", index=False)

# %%
# 코로나 이후 평일 퇴근시간대 추출
weekday_3 = filtered_df[['날짜', '역명', '구분', '17시-18시', '18시-19시', '연도', '월', '일', '요일', '분기', '역전화번호', '도로명주소', '지번주소', '행정동', '위도', '경도', '주간']]
weekday_3.head()
# Out:
#            날짜       역명  구분  17시-18시  18시-19시    연도  월  일 요일  분기         역전화번호  \
# 0  2022-04-01  1호선 서울역  승차     4996     7309  2022  4  1  금   2  02-6110-1331
# 1  2022-04-01  1호선 서울역  하차     3134     3825  2022  4  1  금   2  02-6110-1331
# 2  2022-04-01  1호선 시청역  승차     2832     5687  2022  4  1  금   2  02-6110-1321
# 3  2022-04-01  1호선 시청역  하차      649      771  2022  4  1  금   2  02-6110-1321
# 4  2022-04-01  1호선 종각역  승차     4181     6864  2022  4  1  금   2  02-6110-1311
#
#                         도로명주소                           지번주소     행정동  \
# 0  서울특별시 중구 세종대로 지하2(남대문로 5가)  서울특별시 중구 남대문로5가 73-6 서울역(1호선)  남대문로5가
# 1  서울특별시 중구 세종대로 지하2(남대문로 5가)  서울특별시 중구 남대문로5가 73-6 서울역(1호선)  남대문로5가
# 2     서울특별시 중구 세종대로 지하101(정동)       서울특별시 중구 정동 5-5 시청역(1호선)      정동
# 3     서울특별시 중구 세종대로 지하101(정동)       서울특별시 중구 정동 5-5 시청역(1호선)      정동
# 4     서울특별시 종로구 종로 지하55(종로1가)     서울특별시 종로구 종로1가 54 종각역(1호선)    종로1가
#
#           위도          경도  주간
# 0  37.553150  126.972533  평일
# ...

# %%
# index를 포함하지 않고 데이터 저장
weekday_3.to_csv("코로나 이후 평일 퇴근시간대 승하차인원.csv", index=False)

# %%
# 코로나 이후 평일 야간시간대 추출
weekday_4 = filtered_df[['날짜', '역명', '구분', '22시-23시', '23시-24시', '24시 이후', '연도', '월', '일', '요일', '분기', '역전화번호', '도로명주소', '지번주소', '행정동', '위도', '경도', '주간']]
weekday_4.head()
# Out:
#            날짜       역명  구분  22시-23시  23시-24시  24시 이후    연도  월  일 요일  분기  \
# 0  2022-04-01  1호선 서울역  승차     1738      633     NaN  2022  4  1  금   2
# 1  2022-04-01  1호선 서울역  하차      890      615     NaN  2022  4  1  금   2
# 2  2022-04-01  1호선 시청역  승차      795      317     NaN  2022  4  1  금   2
# 3  2022-04-01  1호선 시청역  하차      117      138     NaN  2022  4  1  금   2
# 4  2022-04-01  1호선 종각역  승차     2131     1300     NaN  2022  4  1  금   2
#
#           역전화번호                       도로명주소                           지번주소  \
# 0  02-6110-1331  서울특별시 중구 세종대로 지하2(남대문로 5가)  서울특별시 중구 남대문로5가 73-6 서울역(1호선)
# 1  02-6110-1331  서울특별시 중구 세종대로 지하2(남대문로 5가)  서울특별시 중구 남대문로5가 73-6 서울역(1호선)
# 2  02-6110-1321     서울특별시 중구 세종대로 지하101(정동)       서울특별시 중구 정동 5-5 시청역(1호선)
# 3  02-6110-1321     서울특별시 중구 세종대로 지하101(정동)       서울특별시 중구 정동 5-5 시청역(1호선)
# 4  02-6110-1311     서울특별시 종로구 종로 지하55(종로1가)     서울특별시 종로구 종로1가 54 종각역(1호선)
#
#       행정동         위도          경도  주간
# 0  남대문로5가  37.553150  126.972533  평일
# ...

# %%
# index를 포함하지 않고 데이터 저장
weekday_4.to_csv("코로나 이후 평일 야간시간대 승하차인원.csv", index=False)

# %% [markdown]
# 주말 데이터 추출

# %%
df.head()
# Out:
#            날짜       역명  구분  06시 이전  06시-07시  07시-08시  08시-09시  09시-10시  \
# 0  2022-04-01  1호선 서울역  승차     315      369     1334     2085     1509
# 1  2022-04-01  1호선 서울역  하차     200     1276     3370     7239     4347
# 2  2022-04-01  1호선 시청역  승차      78      115      238      292      292
# 3  2022-04-01  1호선 시청역  하차     192      658     2391     7239     2957
# 4  2022-04-01  1호선 종각역  승차      80      110      210      329      390
#
#    10시-11시  11시-12시  ...  일  요일  분기         역전화번호                       도로명주소  \
# 0     1361     1696  ...  1   금   2  02-6110-1331  서울특별시 중구 세종대로 지하2(남대문로 5가)
# 1     2056     1790  ...  1   금   2  02-6110-1331  서울특별시 중구 세종대로 지하2(남대문로 5가)
# 2      391      493  ...  1   금   2  02-6110-1321     서울특별시 중구 세종대로 지하101(정동)
# 3     1059      951  ...  1   금   2  02-6110-1321     서울특별시 중구 세종대로 지하101(정동)
# 4      587      891  ...  1   금   2  02-6110-1311     서울특별시 종로구 종로 지하55(종로1가)
#
#                             지번주소     행정동         위도          경도  주간
# ...

# %%
# '요일' 컬럼에서 '토', '일' 데이터 추출
filtered_df_1 = df[df['요일'].astype(str).str.contains('토|일')]
print(filtered_df_1)
# Out:
#                 날짜       역명  구분  06시 이전  06시-07시  07시-08시  08시-09시  09시-10시  \
# 512     2022-04-02  1호선 서울역  승차     307      242      472      923     1227
# 513     2022-04-02  1호선 서울역  하차     190     1263     1357     1749     2510
# 514     2022-04-02  1호선 시청역  승차      49       73      130      187      204
# 515     2022-04-02  1호선 시청역  하차     107      439      394      673      764
# 516     2022-04-02  1호선 종각역  승차      75       93      120      235      263
# ...            ...      ...  ..     ...      ...      ...      ...      ...
# 341237  2024-01-28  8호선 문정역  하차      29      132      143      264      317
# 341238  2024-01-28  8호선 장지역  승차      69      165      204      362      502
# 341239  2024-01-28  8호선 장지역  하차      40      147      275      271      464
# 341240  2024-01-28  8호선 복정역  승차      55       77      124      212      297
# 341241  2024-01-28  8호선 복정역  하차      35      126      155      274      219
#
# ...

# %%
# 코로나 이후 주말 오전시간대 추출
weekend_1 = filtered_df_1[['날짜', '역명', '구분', '06시 이전', '06시-07시', '07시-08시', '08시-09시', '09시-10시', '10시-11시',
                           '연도', '월', '일', '요일', '분기', '역전화번호', '도로명주소', '지번주소', '행정동', '위도', '경도', '주간']]
weekend_1.head()
# Out:
#              날짜       역명  구분  06시 이전  06시-07시  07시-08시  08시-09시  09시-10시  \
# 512  2022-04-02  1호선 서울역  승차     307      242      472      923     1227
# 513  2022-04-02  1호선 서울역  하차     190     1263     1357     1749     2510
# 514  2022-04-02  1호선 시청역  승차      49       73      130      187      204
# 515  2022-04-02  1호선 시청역  하차     107      439      394      673      764
# 516  2022-04-02  1호선 종각역  승차      75       93      120      235      263
#
#      10시-11시    연도  ...  일  요일 분기         역전화번호                       도로명주소  \
# 512     1650  2022  ...  2   토  2  02-6110-1331  서울특별시 중구 세종대로 지하2(남대문로 5가)
# 513     2251  2022  ...  2   토  2  02-6110-1331  서울특별시 중구 세종대로 지하2(남대문로 5가)
# 514      235  2022  ...  2   토  2  02-6110-1321     서울특별시 중구 세종대로 지하101(정동)
# 515      846  2022  ...  2   토  2  02-6110-1321     서울특별시 중구 세종대로 지하101(정동)
# 516      359  2022  ...  2   토  2  02-6110-1311     서울특별시 종로구 종로 지하55(종로1가)
#
#                               지번주소     행정동         위도          경도  주간
# ...

# %%
# index를 포함하지 않고 데이터 저장
weekend_1.to_csv("코로나 이후 주말 오전시간대 승하차인원.csv", index=False)

# %%
# 코로나 이후 주말 오후시간대 추출
weekend_2 = filtered_df_1[['날짜', '역명', '구분', '06시 이전', '11시-12시', '12시-13시', '13시-14시', '14시-15시', '15시-16시',
                           '16시-17시', '17시-18시', '18시-19시', '19시-20시', '20시-21시', '21시-22시', '22시-23시', '23시-24시',
                           '24시 이후', '연도', '월', '일', '요일', '분기', '역전화번호', '도로명주소', '지번주소', '행정동', '위도', '경도', '주간']]
weekend_2.head()
# Out:
#              날짜       역명  구분  06시 이전  11시-12시  12시-13시  13시-14시  14시-15시  \
# 512  2022-04-02  1호선 서울역  승차     307     2298     2367     2314     1889
# 513  2022-04-02  1호선 서울역  하차     190     2151     2293     2115     2081
# 514  2022-04-02  1호선 시청역  승차      49      336      522      577      766
# 515  2022-04-02  1호선 시청역  하차     107     1227     1048     1101     1207
# 516  2022-04-02  1호선 종각역  승차      75      549      907      905     1068
#
#      15시-16시  16시-17시  ...  일  요일  분기         역전화번호  \
# 512     2318     2447  ...  2   토   2  02-6110-1331
# 513     1920     1842  ...  2   토   2  02-6110-1331
# 514     1039     1357  ...  2   토   2  02-6110-1321
# 515     1061      714  ...  2   토   2  02-6110-1321
# 516     1304     1868  ...  2   토   2  02-6110-1311
#
#                           도로명주소                           지번주소     행정동  \
# 512  서울특별시 중구 세종대로 지하2(남대문로 5가)  서울특별시 중구 남대문로5가 73-6 서울역(1호선)  남대문로5가
# ...

# %%
# index를 포함하지 않고 데이터 저장
weekend_2.to_csv("코로나 이후 주말 오후시간대 승하차인원.csv", index=False)
